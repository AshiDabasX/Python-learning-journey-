# %%
name = input("type your name: ")
print("hello " + name + " welcome to my game!")
play = input("do you want to play? ").lower()

if play == "yes":
    print("let's get started!!")
    direction = input("left or right? ")
    if direction == "left":
        print("we went left and fell of a cliff, game over...")
    elif direction == "right":
          choice = input("now we see an apple, do you want it eat it or not? (yes/no)").lower()
          if choice == "yes":
             print("it was poisonous, you die")
          else:
             print("gold blessed you to be the bravest, you won!")
    else:
          print("sorry not a valid reply")


else:
     print("we are not playing....")
# Out:
# type your name: Ash
# hello Ash welcome to my game!
# do you want to play? yes
# let's get started!!
# left or right? right
# now we see an apple, do you want it eat it or not? (yes/no)no
# gold blessed you to be the bravest, you won!
