# %%
place = input("enter a place:")
fruit = input("enter a fruit:")
adjective = input("enter an adjective: ")
verb = input("enter any verb: ")
anything = input("enter anything you please: ")

print(place + " is kind")
print(fruit + " are " + adjective)
print("what else can I " + verb)
print("when I got " + anything)
# Out:
# enter a place:Paris
# enter a fruit:Peaches
# enter an adjective: Platonic
# enter any verb: Play
# enter anything you please: People
# Paris is kind
# Peaches  are Platonic
# what else can I Play
# when I got People

# %% [markdown]
# It was a very fun game, madlibs
# Stay tuned for better projects
